# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

# %%
df = pd.read_csv(r"E:\Jupyter Notebooks\train.csv")

# %%
df.sample()
# Out:
#      PassengerId  Survived  Pclass                  Name   Sex   Age  SibSp  \
# 130          131         0       3  Drazenoic, Mr. Jozef  male  33.0      0
#
#      Parch  Ticket    Fare Cabin Embarked
# 130      0  349241  7.8958   NaN        C

# %%
df = df.drop(['PassengerId','Name','Age','SibSp','Parch','Ticket'], axis = 1)

# %%
df.isnull().mean()*100
# Out:
# Survived     0.000000
# Pclass       0.000000
# Sex          0.000000
# Fare         0.000000
# Cabin       77.104377
# Embarked     0.224467
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Fare      891 non-null    float64
#  4   Cabin     204 non-null    object
#  5   Embarked  889 non-null    object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 41.9+ KB

# %%
df['Cabin'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df['Cabin'].nunique()
# Out:
# 147

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df['Embarked'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
# in the above dataset we found that there are a lot many categories in cabin column
# so taking the below dataset for the analysis

# %%
dfnew = pd.read_csv(r"E:\Jupyter Notebooks\data_science_job.csv")

# %%
dfnew.target.nunique() # can't use this dataset since target is categorical so can't plot kde for this
# Out:
# 2

# %%
dfnew.isnull().mean()
# Out:
# enrollee_id               0.000000
# city                      0.000000
# city_development_index    0.025003
# gender                    0.235306
# relevent_experience       0.000000
# enrolled_university       0.020148
# education_level           0.024011
# major_discipline          0.146832
# experience                0.003393
# company_size              0.309949
# company_type              0.320493
# training_hours            0.039983
# target                    0.000000
# dtype: float64

# %%
#dfnew[dfnew.isnull().mean() > 0] # this gives us error

# %%
dfnew.columns[dfnew.isnull().mean() > 0]
# Out:
# Index(['city_development_index', 'gender', 'enrolled_university',
#        'education_level', 'major_discipline', 'experience', 'company_size',
#        'company_type', 'training_hours'],
#       dtype='object')

# %%
columns = list(dfnew.columns[dfnew.isnull().mean() > 0])

# %%
columns
# Out:
# ['city_development_index',
#  'gender',
#  'enrolled_university',
#  'education_level',
#  'major_discipline',
#  'experience',
#  'company_size',
#  'company_type',
#  'training_hours']

# %%
dfnew = pd.concat([dfnew[columns], dfnew['target']], axis = 1)

# %%
dfnew.head()
# Out:
#    city_development_index gender enrolled_university education_level  \
# 0                   0.920   Male       no_enrollment        Graduate
# 1                   0.776   Male       no_enrollment        Graduate
# 2                   0.624    NaN    Full time course        Graduate
# 3                   0.789    NaN                 NaN        Graduate
# 4                   0.767   Male       no_enrollment         Masters
#
#   major_discipline  experience company_size    company_type  training_hours  \
# 0             STEM        20.0          NaN             NaN            36.0
# 1             STEM        15.0        50-99         Pvt Ltd            47.0
# 2             STEM         5.0          NaN             NaN            83.0
# 3  Business Degree         0.0          NaN         Pvt Ltd            52.0
# 4             STEM        20.0        50-99  Funded Startup             8.0
#
#    target
# 0     1.0
# 1     0.0
# 2     0.0
# 3     1.0
# 4     0.0

# %%
np.round(dfnew.isnull().mean()*100, 2)
# Out:
# city_development_index     2.50
# gender                    23.53
# enrolled_university        2.01
# education_level            2.40
# major_discipline          14.68
# experience                 0.34
# company_size              30.99
# company_type              32.05
# training_hours             4.00
# target                     0.00
# dtype: float64

# %%
freq = dfnew['gender'].mode()

# %%
freq[0]
# Out:
# 'Male'

# %%
dfnew['genderI'] = dfnew['gender'].fillna(freq[0])

# %%
dfnew['gender'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
dfnew['genderI'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
dfnew['target'].plot(kind = 'kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
dfnew[dfnew['genderI']=='male']['target'].plot(kind = 'kde', label = 'imputed with mode')
plt.legend()
#dfnew['gender'].plot(kind = 'kde', label = 'original')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 dfnew[dfnew['genderI']=='male']['target'].plot(kind = 'kde', label = 'imputed with mode')
#       2 plt.legend()
#
# File E:\data_science_apps\lib\site-packages\pandas\plotting\_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
#     969             label_name = label_kw or data.columns
#     970             data.columns = label_name
# --> 972 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File E:\data_science_apps\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...
